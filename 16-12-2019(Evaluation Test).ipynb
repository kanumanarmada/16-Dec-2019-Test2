# %%
import pandas as pd
import numpy as np
import seaborn as snb
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv("Iris.csv")

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
# 1.show the count of different types of species.
iris['Species'].value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
# 2.find the max,m and mean in values of Sepallength, petallength, sepalwidth and petalwidth
m1=max(iris['PetalWidthCm'])
mea1=sum(iris['PetalWidthCm'])/len(iris['PetalWidthCm'])
print("Maximum value in Sepallength is ",pe_ma)
print("Mean Value in Sepallength is ",pe_me)
# Out:
# Maximum value in Sepallength is  2.5
# Mean Value in Sepallength is  1.1986666666666672

# %%
# 3.scatterplot(for sepallength and petallength).
iris.plot(kind='scatter',x='SepalLengthCm', y='PetalLengthCm')

# %%
# 5.jointplot(for sepallength and sepalwidth)
snb.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=iris)

# %%
# 7.boxplot(for species and sepalwidth)
snb.boxplot(x='Species',y='SepalWidthCm',data=iris)

# %%
# 8.boxplot & stripplot(for sepallength and all species)
bp = snb.boxplot(data=iris, x = 'SepalLengthCm',y = 'Species')
st = snb.stripplot(data=iris, x='SepalLengthCm', y='Species')
print(bp)
print(st)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# 9.violinplot(for petallength and all species) 
snb.violinplot(x='PetalLengthCm',y='Species',data=iris)

# %%
# 10.pairplot(for all 4 columns with species)
snb.pairplot(iris.drop('Id', axis=1), hue='Species')
